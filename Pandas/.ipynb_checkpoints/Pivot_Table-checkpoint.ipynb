# %% [markdown]
# ### Pivot Tables

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    118     39   John  January      Q1
# 1  2023-01-02       B   West    556     76   Mary  January      Q1
# 2  2023-01-03       C  North    907     35    Bob  January      Q1
# 3  2023-01-04       D  South    360     33  Alice  January      Q1
# 4  2023-01-05       A   East    190     26   John  January      Q1
# 5  2023-01-06       B   West    710     67   Mary  January      Q1
# 6  2023-01-07       C  North    612     28    Bob  January      Q1
# 7  2023-01-08       D  South    940     83  Alice  January      Q1
# 8  2023-01-09       A   East    429     80   John  January      Q1
# 9  2023-01-10       B   West    291     49   Mary  January      Q1
# 10 2023-01-11       C  North    649     41    Bob  January      Q1
# 11 2023-01-12       D  South    900     63  Alice  January      Q1
# 12 2023-01-13       A   East    919     38   John  January      Q1
# 13 2023-01-14       B   West    738     87   Mary  January      Q1
# 14 2023-01-15       C  North    659     19    Bob  January      Q1
# 15 2023-01-16       D  South    401     72  Alice  January      Q1
# 16 2023-01-17       A   East    832     40   John  January      Q1
# 17 2023-01-18       B   West    631     21   Mary  January      Q1
# 18 2023-01-19       C  North    575     45    Bob  January      Q1
# 19 2023-01-20       D  South    841     81  Alice  January      Q1

# %%
pd.pivot_table(df, values = 'Sales', index = 'Region', columns= 'Product', aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     429.0    NaN    NaN    NaN
# North      NaN    NaN  649.0    NaN
# South      NaN    NaN    NaN  841.0
# West       NaN  631.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values= ['Sales', 'Units'], index = 'Region', columns = 'Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     497.6    NaN    NaN    NaN  44.6   NaN   NaN   NaN
# North      NaN    NaN  680.4    NaN   NaN   NaN  33.6   NaN
# South      NaN    NaN    NaN  688.4   NaN   NaN   NaN  66.4
# West       NaN  585.2    NaN    NaN   NaN  60.0   NaN   NaN

# %% [markdown]
# **Cross Tabs**

# %%
pd.crosstab(df['Region'], df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
